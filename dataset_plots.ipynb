# %%
import pandas as pd
import numpy as np

# %%
# First dataset. Best Video Games of All Time (https://www.kaggle.com/datasets/faisaljanjua0555/best-video-games-of-all-time)
vg_data = pd.read_csv("vg_data.csv")
vg_data
# Out:
#     Rank                                  Name  Unnamed: 2       Platform  \
# 0      1  The Legend of Zelda: Ocarina of Time         NaN    Nintendo 64
# 1      2              Tony Hawk's Pro Skater 2         NaN    PlayStation
# 2      3                   Grand Theft Auto IV         NaN  PlayStation 3
# 3      4                           SoulCalibur         NaN      Dreamcast
# 4      5                   Grand Theft Auto IV         NaN       Xbox 360
# ..   ...                                   ...         ...            ...
# 95    96           Sid Meier's Civilization II         NaN             PC
# 96    97                                 Quake         NaN             PC
# 97    98        Call of Duty 4: Modern Warfare         NaN       Xbox 360
# 98    99                     BioShock Infinite         NaN             PC
# 99   100                                Halo 3         NaN       Xbox 360
#
#     Metascore       Date                                              Title  \
# ...

# %%
# Tidy-up data. Remove columns with missing values
vg_data = vg_data.dropna(axis=1)
vg_data = vg_data.rename(columns={'Title' : 'Description'})
vg_data.head()
# Out:
#    Rank                                  Name       Platform  Metascore  \
# 0     1  The Legend of Zelda: Ocarina of Time    Nintendo 64         99
# 1     2              Tony Hawk's Pro Skater 2    PlayStation         98
# 2     3                   Grand Theft Auto IV  PlayStation 3         98
# 3     4                           SoulCalibur      Dreamcast         98
# 4     5                   Grand Theft Auto IV       Xbox 360         98
#
#         Date                                        Description
# 0  23-Nov-98  As a young boy, Link is tricked by Ganondorf, ...
# 1  20-Sep-00  As most major publishers' development efforts ...
# 2  29-Apr-08  [Metacritic's 2008 PS3 Game of the Year; Also ...
# 3   8-Sep-99  This is a tale of souls and swords, transcendi...
# 4  29-Apr-08  [Metacritic's 2008 Xbox 360 Game of the Year; ...

# %%
vg_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         100 non-null    int64
#  1   Name         100 non-null    object
#  2   Platform     100 non-null    object
#  3   Metascore    100 non-null    int64
#  4   Date         100 non-null    object
#  5   Description  100 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 4.8+ KB

# %%
vg_sales = pd.read_csv("vg_sales.csv")
vg_sales.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# Second dataset. Global Video Games Sales (https://www.kaggle.com/datasets/thedevastator/global-video-game-sales)
#vg_sales["Platform"].replace("NES", "Nintendo", inplace=True)
vg_sales["Platform"] = vg_sales["Platform"].replace("NES", "Nintendo")
vg_sales["Platform"] = vg_sales["Platform"].replace("N64", "Nintendo 64")
vg_sales["Platform"] = vg_sales["Platform"].replace("GC", "GameCube")
vg_sales["Platform"] = vg_sales["Platform"].replace("WiiU", "Wii U")
vg_sales["Platform"] = vg_sales["Platform"].replace("GB", "Game Boy")
vg_sales["Platform"] = vg_sales["Platform"].replace("GBA", "Game Boy Advance")
vg_sales["Platform"] = vg_sales["Platform"].replace("PS", "PlayStation")
vg_sales["Platform"] = vg_sales["Platform"].replace("PS2", "PlayStation 2")
vg_sales["Platform"] = vg_sales["Platform"].replace("PS2", "PlayStation 3")
vg_sales["Platform"] = vg_sales["Platform"].replace("PS2", "PlayStation 4")
vg_sales["Platform"] = vg_sales["Platform"].replace("PS2", "PlayStation 5")
vg_sales["Platform"] = vg_sales["Platform"].replace("XB", "Xbox")
vg_sales["Platform"] = vg_sales["Platform"].replace("X360", "Xbox 360")
vg_sales["Platform"] = vg_sales["Platform"].replace("XOne", "Xbox One")
vg_sales["Platform"] = vg_sales["Platform"].replace("DC", "Dreamcast")
vg_sales
# Out:
#         Rank                                              Name  \
# 0          1                                        Wii Sports
# 1          2                                 Super Mario Bros.
# 2          3                                    Mario Kart Wii
# 3          4                                 Wii Sports Resort
# 4          5                          Pokemon Red/Pokemon Blue
# ...      ...                                               ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5
# 16594  16597                     Men in Black II: Alien Escape
# 16595  16598  SCORE International Baja 1000: The Official Game
# 16596  16599                                        Know How 2
# 16597  16600                                  Spirits & Spells
#
#                Platform    Year         Genre   Publisher  NA_Sales  EU_Sales  \
# 0                   Wii  2006.0        Sports    Nintendo     41.49     29.02
# ...

# %%
vg_sales.head()
# Out:
#    Rank                      Name  Platform    Year         Genre Publisher  \
# 0     1                Wii Sports       Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.  Nintendo  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii       Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort       Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue  Game Boy  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
vg_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
vg_data.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Metascore', 'Date', 'Description'], dtype='object')

# %%
vg_sales.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
##TEST
# joined_data = vg_data.join(vg_sales.set_index(["Rank", "Name", "Platform"]), on=["Rank", "Name", "Platform"], lsuffix="_x", rsuffix="_y")
# joined_data

# %%
##TEST
# new_data = vg_data
# for i in vg_data.index:
#     for j in vg_sales.index:
#         if vg_data["Name"][i] == vg_sales["Name"][j] and vg_data["Platform"][i] == vg_sales["Platform"][j]:
#             #print(vg_data["Name"][i] + " has sales data on the platform: " + f"{vg_sales["Platform"][j]}")
#             #new_data.join(vg_sales["Name"], on=["Name"], lsuffix="_x", rsuffix="_y")
#             #new_data[i] = pd.concat([vg_data["Name"][i], vg_sales["Name"][j]])
#             #print(vg_data.iloc[i, 0:4])
#             break

# %%
merged_data = vg_data.merge(vg_sales, on=["Name", "Platform"], sort=False, suffixes=('', '_sales'))
merged_data
# Out:
#     Rank                                     Name          Platform  \
# 0      1     The Legend of Zelda: Ocarina of Time       Nintendo 64
# 1      2                 Tony Hawk's Pro Skater 2       PlayStation
# 2      4                              SoulCalibur         Dreamcast
# 3      5                      Grand Theft Auto IV          Xbox 360
# 4      6                       Super Mario Galaxy               Wii
# 5      7                     Super Mario Galaxy 2               Wii
# 6      9                       Grand Theft Auto V          Xbox One
# 7     12                       Grand Theft Auto V          Xbox 360
# 8     15                 Tony Hawk's Pro Skater 3     PlayStation 2
# 9     16                             Perfect Dark       Nintendo 64
# 10    19                            Metroid Prime          GameCube
# 11    20                     Grand Theft Auto III     PlayStation 2
# 12    22                     Halo: Combat Evolved              Xbox
# ...

# %%
merged_data.drop(['Year','Rank_sales'], axis=1, inplace=True)
merged_data.head()
# Out:
#    Rank                                  Name     Platform  Metascore  \
# 0     1  The Legend of Zelda: Ocarina of Time  Nintendo 64         99
# 1     2              Tony Hawk's Pro Skater 2  PlayStation         98
# 2     4                           SoulCalibur    Dreamcast         98
# 3     5                   Grand Theft Auto IV     Xbox 360         98
# 4     6                    Super Mario Galaxy          Wii         97
#
#         Date                                        Description     Genre  \
# 0  23-Nov-98  As a young boy, Link is tricked by Ganondorf, ...    Action
# 1  20-Sep-00  As most major publishers' development efforts ...    Sports
# 2   8-Sep-99  This is a tale of souls and swords, transcendi...  Fighting
# 3  29-Apr-08  [Metacritic's 2008 Xbox 360 Game of the Year; ...    Action
# 4  12-Nov-07  [Metacritic's 2007 Wii Game of the Year] The u...  Platform
#
#               Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
merged_data.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Metascore         int64
# Date             object
# Description      object
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
import matplotlib

# %%
merged_data["Global_Sales"].plot();

# %%
merged_data["Global_Sales"].hist();

# %%
from natsort import index_natsorted
merged_data = merged_data.sort_values(by="Date", key=lambda x: np.argsort(index_natsorted(merged_data["Date"])))
merged_data
# Out:
#     Rank                                     Name          Platform  \
# 43    70     Metal Gear Solid V: The Phantom Pain          Xbox One
# 35    58  The Legend of Zelda: A Link to the Past  Game Boy Advance
# 56    98           Call of Duty 4: Modern Warfare          Xbox 360
# 54    93                             Gears of War          Xbox 360
# 13    23                                  NFL 2K1         Dreamcast
# 2      4                              SoulCalibur         Dreamcast
# 33    55                   Gran Turismo 3: A-Spec     PlayStation 2
# 34    56                                   Halo 2              Xbox
# 44    74              The Elder Scrolls V: Skyrim                PC
# 19    31                           The Orange Box          Xbox 360
# 20    32                           The Orange Box                PC
# 23    39   The Legend of Zelda: Twilight Princess          GameCube
# 18    30                          Resident Evil 4          GameCube
# ...

# %%
plt.figure(figsize=(50,10))
plt.plot(merged_data["Date"], merged_data["Global_Sales"])
plt.title("Vigeo Game Global Sales Over Time")
plt.xlabel("Time", fontsize=14)
plt.ylabel("Value", fontsize=14)
plt.tick_params(axis="both", labelsize=10)
plt.show()
